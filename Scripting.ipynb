# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')

from sklearn.feature_extraction.text import TfidfVectorizer
from operator import itemgetter
from nltk.corpus import stopwords
from sklearn.metrics.pairwise import linear_kernel
from sklearn.metrics.pairwise import sigmoid_kernel

from joblib import Parallel, delayed
import joblib

# %%
data = pd.read_csv('data.csv')
data.head()
# Out:
#                                          description  \
# 0  After a long day of handling thorny situations...
# 1  If you haven't experienced the pleasures of ba...
# 2  Rich, black mineral mud, harvested from the ba...
# 3  This liquid soap with convenient pump dispense...
# 4  Remember why you love your favorite blanket? T...
#
#                                                title        asin  ratings  \
# 0  Crabtree &amp; Evelyn - Gardener's Ultra-Moist...  B00004U9V2      4.6
# 1                                   AHAVA Bath Salts  B0000531EN      4.5
# 2      AHAVA Dead Sea Mineral Mud, 8.5 oz, Pack of 4  B0000532JH      3.1
# 3  Crabtree &amp; Evelyn Hand Soap, Gardeners, 10...  B00005A77F      4.7
# 4                                 Soy Milk Hand Crme  B00005NDTD      4.9
#
#    n_ratings
# 0        582
# 1          6
# 2          8
# 3         18
# 4         80

# %%
documents = data['description'].values.astype("U")

vectorizer = TfidfVectorizer(stop_words='english')
features = vectorizer.fit_transform(documents)

# %%
model = joblib.load('kmeans.pkl')
label = model.fit_predict(features)
unique_labels = np.unique(label)

# %%
data['label']=np.array(label)

# %%
tfidf = TfidfVectorizer(min_df=3, max_features=None,
                     strip_accents='unicode', analyzer='word',token_pattern=r'\w{1,}',
                     ngram_range=(1,3), stop_words='english')

tfidf_matrix=tfidf.fit_transform(data['description'])

# %%
sig = sigmoid_kernel(tfidf_matrix,tfidf_matrix)

# %%
indices = pd.Series(data.index,index=data['title'])

# %%
stop = stopwords.words('english')

extras=['benefits<br />','','a','this','that','these','those','to','of','at','with','for','also','is']

stop.append(extras)

# %%
def similarity(result, title):
    desc_vector = tfidf.fit_transform(result['description'].apply(lambda x:x.lower()).apply(lambda x: ' '.join([word for word in x.split() if word not in (stop)])))
    similarity_matrix = linear_kernel(desc_vector, desc_vector)
    
    mapping = pd.Series(result.index, index=result['title'])
    product_index = mapping[title]
    
    similarity_score = list(enumerate(similarity_matrix[product_index]))
    
    similarity_score = sorted(similarity_score, key=lambda x: x[1], reverse=True)
    
    list_similarity = []
    for i in range(len(similarity_score)):
        list_similarity.append(similarity_score[i][1])
    
    result['similarity'] = list_similarity
    
    return result

# %%
def get_rec(title,sig=sig):
    i=indices[title]
    x=data.iloc[i]['label']
    t=[x]
    idx=list(data[data['label'].isin(t)].index)
    sig_temp=list(enumerate(sig[i]))

    sig_scores=itemgetter(*idx)(sig_temp)
    
    scores=sorted(sig_scores, key=lambda x:x[0], reverse=True)
    
    product_indices=[i[0] for i in scores]
    
    result = data.iloc[product_indices]
    result=result.reset_index(drop=True)

    output = similarity(result, title)
    output.drop(['label'], axis=1, inplace=True)
    
    return output[['title','description','asin','ratings','n_ratings']][:20]

# %%
result=get_rec('OPI Nail Lacquer Top Coat')
result
# Out:
#                                                 title  \
# 0                        CND Shellac, Leather Satchel
# 1                CND Shellac power polish denim patch
# 2             CND Shellac Power Polish, Patina Buckle
# 3                             CND Shellac, Brick Knit
# 4   ELEMIS Frangipani Monoi Hand Cream and Nail Cr...
# 5                The Beachwaver Co. S.75 Curling Iron
# 6                        JINsoon  Nail Lacquer, Crush
# 7                           butter LONDON Nail Polish
# 8                      butter LONDON Glazen Eye Gloss
# 9    JINsoon Floral Nail Lacquer, Blush, 0.37 fl. oz.
# 10                      theBalm Balm Beach Face Blush
# 11           Laura Geller New York Illuminating stick
# 12               Laura Geller Chocolates Delights Kit
# 13                 Laura Geller New York Spackle Mist
# 14              Laura Geller New York Brow Gel Pencil
# 15        Laura Geller The Delectable Smokey Neutrals
# 16  Laura Geller Chocolates Delights 6 Piece Kit- ...
# 17                     3LAB Anti-Aging Eye Lift, 1 oz
# 18                  amika Show Off Gold Dust, 0.35 oz
# 19  Tan Towel SPF 30 Bronzing Sunscreen Mist, 6 Fl Oz
#
#                                           description        asin  ratings  \
# 0   CND Shellac was designed to be used as a syste...  B01HIQEOLO      5.0
# 1   CND Shellac was designed to be used as a syste...  B01HIQHQU0      4.5
# 2    CND Craft Culture Collection: Patina Buckle D...  B01HIQIEYC      4.4
# 3   CND Shellac was designed to be used as a syste...  B01HIQCSBC      4.0
# 4   This luxurious hand and nail cream, enriched w...  B01HGSJPWM      5.0
# 5   Rotate your way to perfect waves with the Beac...  B01HG7OIT8      4.0
# 6   All jinsoon formulas are 5-free: formulated wi...  B01H353AB0      4.2
# 7   Get the perfect nude pout with our plush rush ...  B01H353HOK      4.3
# 8   A new trick in your beauty arsenal, glazen eye...  B01H353CWW      4.0
# 9   All jinsoon formulas are 5-free: formulated wi...  B01H353ABU      4.0
# 10  It's time to sit back and relax with theBalm C...  B01H2QS8KS      5.0
# 11  Let your best features glow! Long-wearing and ...  B01H1V7VQG      4.2
# 12  Start off fresh and flawless with Spackle prim...  B01H1V7YA4      5.0
# 13  Prime, hydrate, and set your make-up with just...  B01H1V7WSI      4.5
# 14  This easy to use brow pencil creates shaped an...  B01H1V7VOS      3.3
# 15  Indulge in 14 smokey and neutral-toned shades ...  B01H1V7WS8      4.2
# 16  From an early age, Laura Geller has had a love...  B01H1V7Y86      4.8
# 17  This scientifically engineered, marine-based e...  B01H1MGTFY      3.5
# 18  Little Shimmer. Highlight your best assets wit...  B01GW2DITO      3.9
# 19  Broad spectrum spf 30 bronzing mist give you a...  B01GVXG8KU      5.0
#
#     n_ratings
# 0          11
# 1          14
# 2          25
# 3           6
# 4           3
# 5          23
# 6           4
# 7          25
# 8          54
# 9           2
# 10          4
# 11         10
# 12          2
# 13          2
# 14         12
# 15          4
# 16          4
# 17          2
# 18         13
# 19          1
